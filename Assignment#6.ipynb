# %% [markdown]
# <h1>Assignemnt 6<h1>

# %%
#import libraries

import requests
from bs4 import BeautifulSoup
from nltk.corpus import wordnet

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from nltk.probability import FreqDist

from nltk.sentiment import vader
nltk.download('vader_lexicon')

import pandas as pd
from pathlib import Path  
import glob

from nltk.stem.porter import PorterStemmer
# !pip install gensim

from gensim import corpora, models
import gensim
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ...

# %% [markdown]
# <h3>Romeo and Juliet Text Analysis<h3>

# %%
url = 'https://www.gutenberg.org/cache/epub/1112/pg1112.txt'
response = requests.get(url)
document = response.text

# %%
print(document)
# Out:
# ﻿The Project Gutenberg EBook of Romeo and Juliet, by William Shakespeare
#
#
# *******************************************************************
# THIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A
# TIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED. THERE
# IS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK
# (#1513) at https://www.gutenberg.org/ebooks/1513
# *******************************************************************
#
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org/license
#
#
# Title: Romeo and Juliet
#
# Author: William Shakespeare
#
# Posting Date: May 25, 2012 [EBook #1112]
# Release Date: November, 1997  [Etext #1112]
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK ROMEO AND JULIET ***
#
#
#
#
# ...

# %%
sentences = sent_tokenize(document)

# %%
sentences
# Out:
# ["\ufeffThe Project Gutenberg EBook of Romeo and Juliet, by William Shakespeare\r\n\r\n\r\n*******************************************************************\r\nTHIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A\r\nTIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED.",
#  'THERE\r\nIS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK\r\n(#1513) at https://www.gutenberg.org/ebooks/1513\r\n*******************************************************************\r\n\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.',
# ...

# %%
words = word_tokenize(document.lower())

# %%
myStopWords = list(punctuation) + stopwords.words('english')

# %%
wordsNoStopWords = [w for w in words if w not in myStopWords]

# %%
wordsNoStopWords
# Out:
# ['\ufeffthe',
#  'project',
#  'gutenberg',
#  'ebook',
#  'romeo',
#  'juliet',
#  'william',
#  'shakespeare',
#  'ebook',
#  'one',
#  'project',
#  'gutenberg',
#  "'s",
#  'early',
#  'files',
#  'produced',
#  'time',
#  'proofing',
#  'methods',
#  'tools',
#  'well',
#  'developed',
#  'improved',
#  'edition',
#  'title',
#  'may',
#  'viewed',
#  'ebook',
#  '1513',
#  'https',
#  '//www.gutenberg.org/ebooks/1513',
#  'ebook',
#  'use',
#  'anyone',
#  'anywhere',
#  'cost',
#  'almost',
#  'restrictions',
#  'whatsoever',
#  'may',
#  'copy',
#  'give',
#  'away',
#  're-use',
#  'terms',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'ebook',
#  'online',
#  'www.gutenberg.org/license',
#  'title',
#  'romeo',
#  'juliet',
#  'author',
#  'william',
#  'shakespeare',
#  'posting',
#  'date',
#  'may',
#  '25',
#  '2012',
#  'ebook',
#  '1112',
#  'release',
#  'date',
#  'november',
#  '1997',
#  'etext',
#  '1112',
#  'language',
#  'english',
#  'start',
# ...

# %%
freq = FreqDist(wordsNoStopWords)

# %%
freq
# Out:
# FreqDist({"'s": 294, 'thou': 278, "'d": 224, 'thy': 164, 'rom': 163, 'romeo': 158, 'nurse': 148, 'love': 145, 'thee': 136, 'jul': 117, ...})

# %%
for i in sorted(freq, key=freq.get, reverse=True)[:10]:
    print(i,freq[i])
# Out:
# 's 294
# thou 278
# 'd 224
# thy 164
# rom 163
# romeo 158
# nurse 148
# love 145
# thee 136
# jul 117

# %%
ranking = {}

for sentence in sentences:
    ranking[sentence] = 0
    for word in word_tokenize(sentence.lower()):
        if word in freq:
            ranking[sentence] += freq[word]
            
ranking
# Out:
# {"\ufeffThe Project Gutenberg EBook of Romeo and Juliet, by William Shakespeare\r\n\r\n\r\n*******************************************************************\r\nTHIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A\r\nTIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED.": 997,
#  'THERE\r\nIS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK\r\n(#1513) at https://www.gutenberg.org/ebooks/1513\r\n*******************************************************************\r\n\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.': 151,
# ...

# %%
sorted(ranking, key=ranking.get, reverse=True)[:5]
# Out:
# ["Take thou this vial, being then in bed,\r\n    And this distilled liquor drink thou off;\r\n    When presently through all thy veins shall run\r\n    A cold and drowsy humour; for no pulse\r\n    Shall keep his native progress, but surcease;\r\n    No warmth, no breath, shall testify thou livest;\r\n    The roses in thy lips and cheeks shall fade\r\n    To paly ashes, thy eyes' windows fall\r\n    Like death when he shuts up the day of life;\r\n    Each part, depriv'd of supple government,\r\n    Shall, stiff and stark and cold, appear like death;\r\n    And in this borrowed likeness of shrunk death\r\n    Thou shalt continue two-and-forty hours,\r\n    And then awake as from a pleasant sleep.",
# ...

# %%
for sentence in sentences:
    if sentence in sorted(ranking, key=ranking.get, reverse=True)[:5]:
        print(sentence)
# Out:
# Come, night; come, Romeo; come, thou day in night;
#     For thou wilt lie upon the wings of night
#     Whiter than new snow upon a raven's back.
# Thy noble shape is but a form of wax
#     Digressing from the valour of a man;
#     Thy dear love sworn but hollow perjury,
#     Killing that love which thou hast vow'd to cherish;
#     Thy wit, that ornament to shape and love,
#     Misshapen in the conduct of them both,
#     Like powder in a skilless soldier's flask,
#     is get afire by thine own ignorance,
#     And thou dismemb'red with thine own defence.
# Day, night, late, early,
#     At home, abroad, alone, in company,
#     Waking or sleeping, still my care hath been
#     To have her match'd; and having now provided
#     A gentleman of princely parentage,
#     Of fair demesnes, youthful, and nobly train'd,
#     Stuff'd, as they say, with honourable parts,
#     Proportion'd as one's thought would wish a man-
#     And then to have a wretched puling fool,
# ...

# %% [markdown]
# <h3>Yelp Analysis<h3>

# %%
#5 star
r1 = "Excellent customer service.  The bartender Rick is the best. Great customer services and beyond friendly. He is one of the best parts of Ws. Even when people are rude  (which happens with a every business lol) he handles it with such kindness and grace. But on the most part customers are great and he remembers them all when they return :-))"

#5 star
r2 = "I love this place.  This is the third time I have been here and the staff and food are amazing. They have locals here but they treat everyone amazing! Rick the bartender is just absolutely amazing, friendly and great customer service! This place is a must for anytime of day :-)"

#5 star
r3 = "We have been going to Ws since it opened. Covid was terrible as many wonderful restaurants did not survive thank goodness Ws was not one of them . We are meeting our good friends their tonight as we used to before the   INSANITY started. Every dish we have ever had is superb. One last word to the review regarding the crackling calamari being bad. This is one of the most delicious orders to get here if not in the whole South Bay. Go and enjoy the wonderful food, friendly staff and great cocktails and judge for yourself just order the calamari you won't be disappointed. Can't wait"

#5 star
r4 = "I highly recommend this restaurant, the host Nathaniel is amazing. The food is great, we've got our table on time there seems to be a weight most of the time, but call ahead and ask for Nathaniel"

#5 star
r5 = "We may have gone overboard with ordering, but I had to try everything. And honestly, it was good ‍ I'd recommend the Mongolian Beef, my personal favorite from the night. "

#5 star
r6 = "The spirit lives at W's China Bistro. The menu is very similar and many of the options offered at Chong's are available at W's...with the notable exception of the Chicken Eggrolls. "

#5 star
r7 = "This place has a nice, modern Chinese vibe to the place. Very sleek and inviting space. We were greeted warmly by the host and the waiter was super nice and very attentive. "

#5 star
r8 = "There's no need to explain how everything tasted. All I can say it was like a huge party in my mouth. Everything tasted so delicious. We asked the chef to make our dishes spicier than average and he came through with the heat! "

#5 star
r9 = "The staff here is friendly and the service is great. Must've been asked 5-6 times if we needed anything. They're very attentive and polite. I needed a refill on my sprite and before I could ask for it, it appeared in front of me like magic. "

#3 star
r10 = "The food and service here was okay - I ordered the Orange chicken, Chicken fried rice, Crackling Calamari, and Hot and Sour soup. The favorite out of the choices was the Hot and Sour soup - it was the right amount of tangy and very flavorful. You can ask to order a smaller portion of the Chicken fried rice and that was what I opted to do. "

#3 star
r11 = "The biggest letdown for me was the Crackling Calamari. It was wayyy too chewy and bland. It really didn't taste like anything and the dipping sauce didn't really make it taste any better. In the end, I ended up with a whole plate left and didn't even want it for leftovers. I would recommend skipping this one and save yourself that $6 for something else. "

#5 star
r12 = "We love the Pork Belly Banh Mi Sliders, Cantonese Spareribs, the fiery fish with pickled vegetables and always order them. We have tried some other menu items to round out the meal and haven't been disappointed in any of them. The chicken and beef options are satisfactory, but don't really stand out the way the three mentioned items do to me."

#5 star
r13 = "My wife especially loves the pickled vegetables with the fiery fish. She was born and raised in Taiwan and says it is exactly how she remembers them from back there. She liked it so much we asked if we could purchase a container of them on our second visit. I think they were surprised and didn't know what to do or how much to charge. The waiter came out with a pint container and said 5 dollars. We may have been the very first to ever request them. Now I see that it is a regular item you can order."

#4 star
r14 = "We have been going to Ws since it opened. Covid was terrible as many wonderful restaurants did not survive thank goodness Ws was not one of them . We are meeting our good friends their tonight as we used to before the   INSANITY started. Every dish we have ever had is superb. One last word to the review regarding the crackling calamari being bad. This is one of the most delicious orders to get here if not in the whole South Bay. Go and enjoy the wonderful food, friendly staff and great cocktails and judge for yourself just order the calamari you won't be disappointed. Can't wait"

#4 star
r15 = "Prolly one of the best Chinese we've had in LA, although it seems more Americanized in the decor and operation. We got Mongolian beef, orange chicken, side order of veggies, crab rangoon and spring rolls (huge rolls) and they're all very yummy and neat (not oily at all compared to most other places). We got takeout but I think it can be a dining place as well. Can't be more happy!"

# %%
sia = vader.SentimentIntensityAnalyzer()

# %%
#r1
sia.polarity_scores(r1)
# Out:
# {'neg': 0.025, 'neu': 0.633, 'pos': 0.341, 'compound': 0.9749}

# %%
#r2
sia.polarity_scores(r2)
# Out:
# {'neg': 0.0, 'neu': 0.549, 'pos': 0.451, 'compound': 0.9881}

# %%
#r3
sia.polarity_scores(r3)
# Out:
# {'neg': 0.111, 'neu': 0.645, 'pos': 0.245, 'compound': 0.9634}

# %%
#r4
sia.polarity_scores(r4)
# Out:
# {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.7047}

# %%
#r5
sia.polarity_scores(r5)
# Out:
# {'neg': 0.0, 'neu': 0.614, 'pos': 0.386, 'compound': 0.9442}

# %%
#r6
sia.polarity_scores(r6)
# Out:
# {'neg': 0.0, 'neu': 0.946, 'pos': 0.054, 'compound': 0.1779}

# %%
#r7
sia.polarity_scores(r7)
# Out:
# {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.9419}

# %%
#r8
sia.polarity_scores(r8)
# Out:
# {'neg': 0.043, 'neu': 0.71, 'pos': 0.247, 'compound': 0.8843}

# %%
#r9
sia.polarity_scores(r9)
# Out:
# {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.8689}

# %%
#r10
sia.polarity_scores(r10)
# Out:
# {'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'compound': 0.5994}

# %%
#r11
sia.polarity_scores(r11)
# Out:
# {'neg': 0.052, 'neu': 0.824, 'pos': 0.124, 'compound': 0.7188}

# %%
#r12
sia.polarity_scores(r12)
# Out:
# {'neg': 0.026, 'neu': 0.879, 'pos': 0.095, 'compound': 0.531}

# %%
#r13
sia.polarity_scores(r13)
# Out:
# {'neg': 0.024, 'neu': 0.89, 'pos': 0.086, 'compound': 0.7425}

# %%
#r14
sia.polarity_scores(r14)
# Out:
# {'neg': 0.111, 'neu': 0.645, 'pos': 0.245, 'compound': 0.9634}

# %%
#r15
sia.polarity_scores(r15)
# Out:
# {'neg': 0.055, 'neu': 0.817, 'pos': 0.128, 'compound': 0.5716}

# %% [markdown]
# It seems vader under wieghts postive reviews and over wieghts negetive sentiment

# %% [markdown]
# <h3> Movies<h3>

# %%
#Comedies: "10 Things I Hate About You"
cr1 = "I'm not a big fan of teen comedies. They mostly are lame, trading on the same old plots and clichés that have been around since Animal House and Porkies. The recent trend has just seen classical texts adapted giving rise to some poor films like `She's all that'. The plot for this is basically `The Taming of the Shrew' updated - most of it bares little resemblance to the play but that doesn't matter - the core is interesting enough to stand on it's own. It may not surprise you in terms of who gets which girl and it's fairly predictable in a romantic comedy type way but that's not it."
cr2 = "Looking back, this movie had a pretty (no pun intended) decent cast. The now deceased Heath Ledger and Julia Stiles as front runners of course. It is a pretty good romantic teen comedy, that is pretty nice. And that's saying something, if you consider the fact, that it came out the same year, American Pie was."
cr3 = "This film, loosely based on Shakespeare's 'The Taming of the Shrew' is set in a high school near Seattle. New student Cameron James is smitten by Bianca Stratford; there are two major problems though; she is keen on the wealthy Joey Donner, who also likes her, and her father has banned her and her older sister Kat from dating till they graduate high school. This latter rule is changed to state that Bianca can only date when her sister does... potentially a stricter rule as she appears to show only contempt for boys and they are all scared of her. Cameron tutors her hoping to get closer and when he learns of the rule he, and his friend Michael, plot to find a boyfriend for Kat. The candidate for this role is bad boy Patrick Verona; he will need some persuading though. Here things get complicated as he approaches Joey suggesting he pay Patrick to date Kat... inevitably things get a bit messy."
cr4 = "This is really interesting. Is this really a talented actress (only 19) who understands something of Shakespeare and has purposefully targeted film adaptations? I've heard she was a success on TeeVee. I have to know, wondering if the flash of brilliance in Hamlet was a one-shot deal."
cr5 = "I never came across Julia Stiles until the Bourne trilogy, and then I caught her in a quirky little film called The Business of Strangers. This performance here makes me want to see everything she has done. She was just fantastic and I am totally in love with her! Heath ledger was also perfect in this film. You can see why he became the star that he was until this week. I understand this film made him and you can certainly see why."

#Drama: "The Shawshank Redemption"

dr1 = "not for a reason. but for the fine art to create a story who seems be more than fiction and who use a script, a cast and location for a puzzle who becomes part of precious memories. its themes, the tension, the moral questions, the meeting between Morgan Freeman and Tim Robbins and the result of dialogs who are truth axis of movie and wise adaptation, are bones of a splendid film. a film who reminds more than presents. values, roots of justice, beauty of original source, the end who is expression of a deep expectation of the viewer are elements who transforms The Shawshank Redemption in an experience for the viewer. short - a film who must see !"
dr2 = "It is no wonder that the film has such a high rating, it is quite literally breathtaking. What can I say that hasn't said before? Not much, it's the story, the acting, the premise, but most of all, this movie is about how it makes you feel. Sometimes you watch a film, and can't remember it days later, this film loves with you, once you've seen it, you don't forget."
dr3 = "It contains a colorful and evocative cinematography by Roger Deakins . And an enjoyable and really feeling musical score by Thomas Newman . In his engrossing direction debut ,Darabont avoids boring by fleeing most prison movie cliches . It results to be a pleasure of discovering a first-time filmmaker with evident respect for the intelligence of his audience , giving sensitive scenes , and brave enough to let roles details accumulate without recourse the excessively maudlin and over-sentimentality. It is a true masterpiece , being marvelously acted and perfectly paced."
dr4 = "This film is probably the best life-in-prison film ever made. It depicts one man's time in the big house for something he (supposedly) didn't do. This man is Andy Dusfresne (pronounced Duframe) played in his best ever, Tim Robbins. But he isn't alone; he is joined by fellow inmate (who is the only guilty person in Shawshank) Red played also very well by Morgan Freeman. Freeman narrates the life in The Shawshank prison all the way up until the end (not to mention some very memorable escape scenes). Very memorable, showing what movies are made of. Based on Stephen King's novel (one of his best) and adapted for the screen and directed by Frank Darabont, who 5 years later would write and direct the Green Mile, another good (but can't be matched to this one) prison movie. A++"
dr5 = "If you love Shawshank then it's a love that lasts a lifetime. Every viewing brings the same array of emotions - anger - revilement - happiness - sadness - inspiration and a warmth that can reduce the most hardened into misty eyed wonderment. Above all else, though, Shawshank offers hope - not just for characters in a movie - but for a better life and a better world for all of us. 10/10"

# %%
listOfMovies = [cr1,cr2,cr3,cr4,cr5,dr1,dr2,dr3,dr4,dr5]

# %%
len(listOfMovies)
# Out:
# 10

# %%
extrastop = ['``',"''","'re","'s","'re",'``',"''","'ll","--","\'\'","...",
             "n\'t",'one','would','use','subject','from',"\'m","\'ve"]

# %%
myStopWords = list(punctuation) + stopwords.words('english') + extrastop

# %%
[w for w in word_tokenize(listOfMovies[0].lower()) if w not in myStopWords]
# Out:
# ['big',
#  'fan',
#  'teen',
#  'comedies',
#  'mostly',
#  'lame',
#  'trading',
#  'old',
#  'plots',
#  'clichés',
#  'around',
#  'since',
#  'animal',
#  'house',
#  'porkies',
#  'recent',
#  'trend',
#  'seen',
#  'classical',
#  'texts',
#  'adapted',
#  'giving',
#  'rise',
#  'poor',
#  'films',
#  'like',
#  'plot',
#  'basically',
#  'taming',
#  'shrew',
#  'updated',
#  'bares',
#  'little',
#  'resemblance',
#  'play',
#  'matter',
#  'core',
#  'interesting',
#  'enough',
#  'stand',
#  'may',
#  'surprise',
#  'terms',
#  'gets',
#  'girl',
#  'fairly',
#  'predictable',
#  'romantic',
#  'comedy',
#  'type',
#  'way']

# %%
listOfMoviesWords = []
for i in listOfMovies:
    listOfMoviesWords.append([w for w in word_tokenize(i.lower()) if w not in myStopWords])

# %%
listOfMoviesWords[0]
# Out:
# ['big',
#  'fan',
#  'teen',
#  'comedies',
#  'mostly',
#  'lame',
#  'trading',
#  'old',
#  'plots',
#  'clichés',
#  'around',
#  'since',
#  'animal',
#  'house',
#  'porkies',
#  'recent',
#  'trend',
#  'seen',
#  'classical',
#  'texts',
#  'adapted',
#  'giving',
#  'rise',
#  'poor',
#  'films',
#  'like',
#  'plot',
#  'basically',
#  'taming',
#  'shrew',
#  'updated',
#  'bares',
#  'little',
#  'resemblance',
#  'play',
#  'matter',
#  'core',
#  'interesting',
#  'enough',
#  'stand',
#  'may',
#  'surprise',
#  'terms',
#  'gets',
#  'girl',
#  'fairly',
#  'predictable',
#  'romantic',
#  'comedy',
#  'type',
#  'way']

# %%
p_stemmer = PorterStemmer()

# %%
listOfStemmedWords = []
for i in listOfMoviesWords:
    listOfStemmedWords.append([p_stemmer.stem(w) for w in i])

# %%
listOfStemmedWords[0]
# Out:
# ['big',
#  'fan',
#  'teen',
#  'comedi',
#  'mostli',
#  'lame',
#  'trade',
#  'old',
#  'plot',
#  'cliché',
#  'around',
#  'sinc',
#  'anim',
#  'hous',
#  'porki',
#  'recent',
#  'trend',
#  'seen',
#  'classic',
#  'text',
#  'adapt',
#  'give',
#  'rise',
#  'poor',
#  'film',
#  'like',
#  'plot',
#  'basic',
#  'tame',
#  'shrew',
#  'updat',
#  'bare',
#  'littl',
#  'resembl',
#  'play',
#  'matter',
#  'core',
#  'interest',
#  'enough',
#  'stand',
#  'may',
#  'surpris',
#  'term',
#  'get',
#  'girl',
#  'fairli',
#  'predict',
#  'romant',
#  'comedi',
#  'type',
#  'way']

# %%
dictionary = corpora.Dictionary(listOfStemmedWords)

# %%
print(dictionary.token2id)
# Out:
# {'adapt': 0, 'anim': 1, 'around': 2, 'bare': 3, 'basic': 4, 'big': 5, 'classic': 6, 'cliché': 7, 'comedi': 8, 'core': 9, 'enough': 10, 'fairli': 11, 'fan': 12, 'film': 13, 'get': 14, 'girl': 15, 'give': 16, 'hous': 17, 'interest': 18, 'lame': 19, 'like': 20, 'littl': 21, 'matter': 22, 'may': 23, 'mostli': 24, 'old': 25, 'play': 26, 'plot': 27, 'poor': 28, 'porki': 29, 'predict': 30, 'recent': 31, 'resembl': 32, 'rise': 33, 'romant': 34, 'seen': 35, 'shrew': 36, 'sinc': 37, 'stand': 38, 'surpris': 39, 'tame': 40, 'teen': 41, 'term': 42, 'text': 43, 'trade': 44, 'trend': 45, 'type': 46, 'updat': 47, 'way': 48, 'american': 49, 'back': 50, 'came': 51, 'cast': 52, 'consid': 53, 'cours': 54, 'deceas': 55, 'decent': 56, 'fact': 57, 'front': 58, 'good': 59, 'heath': 60, 'intend': 61, 'julia': 62, 'ledger': 63, 'look': 64, 'movi': 65, 'nice': 66, 'pie': 67, 'pretti': 68, 'pun': 69, 'runner': 70, 'say': 71, 'someth': 72, 'stile': 73, 'year': 74, "'the": 75, 'also': 76, 'appear': 77, 'approach'
# ...
